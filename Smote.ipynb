# %% [markdown]
# <a href="https://colab.research.google.com/github/asawariP/StatWithPython/blob/main/Smote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification

# %%
#X = independant feature
# y = independat feature
x,y = make_classification(n_samples=1000,n_features=2,n_redundant=0,n_clusters_per_class=1,weights=[0.90],random_state=1)

# %%
from re import X
import pandas as pd
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df =pd.concat([df1,df2],axis =1)

# %%
final_df
# Out:
#            f1        f2  target
# 0    1.536830 -1.398694       1
# 1    1.551108  1.810329       0
# 2    1.293619  1.010946       0
# 3    1.119889  1.632518       0
# 4    1.042356  1.121529       0
# ..        ...       ...     ...
# 995  2.210439  2.006772       0
# 996  1.910941  2.011860       0
# 997 -0.556625 -0.159837       0
# 998  1.004999  0.936290       0
# 999  1.462110  1.144978       0
#
# [1000 rows x 3 columns]

# %%
final_df['target'].value_counts()
# Out:
# 0    894
# 1    106
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
##tranform the dataset
oversample =SMOTE()
x,y = oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1788, 2)

# %%
y.shape
# Out:
# (1788,)

# %%
len(y[y==1])
# Out:
# 894

# %%
df1 = pd.DataFrame(x,columns=['f1','f2'])
df2 = pd.DataFrame(y,columns=['target'])
final_df =pd.concat([df1,df2],axis =1)

# %%
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])
